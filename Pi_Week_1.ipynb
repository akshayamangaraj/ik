# %% [markdown]
# <a href="https://colab.research.google.com/github/akshayamangaraj/ik/blob/Week-1/Pi_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1

# %% [markdown]
# Python:Fundamental:1

# %%
# Comment 1
""" Multi-line comments
2nd line """
"""Multi-line comments"""
print(" Hello Print")

a=3
b="Hello steing"
bool= True
print( b)
print(bool)
# Out:
#  Hello Print
# Hello steing
# True

# %%
type(b)
type(bool)
print(type(bool))

3**2
a=5
b=5.0
print(a==b)
print(a is b)
user_intput=input("Please privice yur age")
print(user_intput)

# Modified section to handle age input and conversion robustly
while True:
    age_str = input("Enter age (must be a number): ")
    try:
        age = int(age_str)
        print(f"Your age is: {age}")
        break # Exit the loop if valid input is received
    except ValueError:
        print(f"Invalid input: '{age_str}' is not a valid number. Please try again.")

# This line will now reflect the type of the validated 'age' variable
print(type(age))
# Out:
# <class 'bool'>
# True
# False
# Please privice yur age11
# 11
# Enter age (must be a number): 2s
# Invalid input: '2s' is not a valid number. Please try again.
# Enter age (must be a number): re
# Invalid input: 're' is not a valid number. Please try again.
# Enter age (must be a number): 12
# Your age is: 12
# <class 'int'>
